# %%
# !python -m site
# Out:
# sys.path = [
#     '/mnt/c/Windows/system32',
#     '/home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python310.zip',
#     '/home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10',
#     '/home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/lib-dynload',
#     '/home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages',
# ]
# USER_BASE: '/home/ubuntu-marcelo/.local' (exists)
# USER_SITE: '/home/ubuntu-marcelo/.local/lib/python3.10/site-packages' (doesn't exist)
# ENABLE_USER_SITE: True

# %%
# !pip install \
#     --extra-index-url=https://pypi.nvidia.com \
#     cuml-cu11

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Mon_Oct_24_19:12:58_PDT_2022
# Cuda compilation tools, release 12.0, V12.0.76
# Build cuda_12.0.r12.0/compiler.31968024_0

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (3.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (2.0.21)
# Requirement already satisfied: tqdm in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ubuntu-marcelo/miniconda3/envs/rapids-23.08/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
google_id = '1teoxduT3bJAkrD0k1YIPn-mbVI83oQox'
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id=google_id,
                                    dest_path = './dados_cvm.csv',
                                    showsize = True)


google_id = '1J0fF-82tDg70wjaNg2Q8OGxPikA7phqp'
gdd.download_file_from_google_drive(file_id=google_id,
                                    dest_path = './dados_classes.csv',
                                    showsize = True)


google_id = '12Ior9IH6xpACUIP0qRWCvGNRs9774150'
gdd.download_file_from_google_drive(file_id=google_id,
                                    dest_path = './synthetic_data_realistic.csv',
                                    showsize = True)

# %%
df_1 = pd.read_csv('dados_cvm.csv')
df_2 = pd.read_csv('dados_classes.csv')
df = pd.merge(df_1, df_2, on='SK_Documento', how='inner')
# Out:
# /tmp/ipykernel_6709/529873874.py:1: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv('dados_cvm.csv')

# %% [markdown]
# # Passo 1: Agregar cotas em Subordinadas e Senior por fundo

# %%
print(f"{len(df.loc[df['Patrimonio_Liquido'] == 0]) / len(df.index) * 100}% dos fundos tem PL == 0")
# Out:
# 1.281484012254751% dos fundos tem PL == 0

# %%
print(f"{len(df.loc[df['Patrimonio_Liquido'] < 0]) / len(df.index) * 100}% dos fundos tem PL < 0")
# Out:
# 0.09073444492363185% dos fundos tem PL < 0

# %%
print(f"Pré-operação tinhamos {len(df.columns)} colunas e {len(df.index)} linhas")
print(f"Pré-operação tinhamos {df['Classe_Serie'].nunique()} dados únicos na coluna Classe_Serie")

df.loc[df['Classe_Serie'].str.contains("sub", case=False), 'Classe_Serie'] = "Subordinada"
df.loc[df['Classe_Serie'].str.contains("nior", case=False), 'Classe_Serie'] = "Senior"

print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
print(f"Agora temos {df['Classe_Serie'].nunique()} dados únicos na coluna Classe_Serie")
# Out:
# Pré-operação tinhamos 336 colunas e 178543 linhas
# Pré-operação tinhamos 57 dados únicos na coluna Classe_Serie
# Agora temos 336 colunas e 178543 linhas
# Agora temos 2 dados únicos na coluna Classe_Serie

# %%
# Agora vamos criar colunas agregando as 'cols_to_sum' por Subordinada e Senior
classe_serie_types = ["Subordinada", "Senior"]
cols_to_sum = ["Numero_Cotistas", "Quantidade_Cotas", "Valor_Cota", "Rentabilidade", "Valor_Total_Captado", "Quantidade_Cotas_Emitidas", "Valor_Total_Resgates", "Quantidade_Cotas_Resgatadas", "Valor_A_Pagar", "Quantidade_Cotas_A_Resgatar", "Valor_Amortizado_Cota", "Valor_Total_Amortizacao", "Desempenho_Esperado", "Desempenho_Realizado"]
for classe_serie_type in classe_serie_types:
  for col in cols_to_sum:
    df[col + "_" + classe_serie_type] = df[df['Classe_Serie'] == classe_serie_type].groupby('ID_Documento')[col].transform('sum')

print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Agora temos 364 colunas e 178543 linhas

# %%
# Agora vamos remover fileiras duplicadas
df.drop(cols_to_sum, axis=1, inplace=True)
df = df.drop_duplicates()
print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Agora temos 350 colunas e 111476 linhas

# %%
df = df.groupby("ID_Documento", as_index=False).agg("first")
print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Agora temos 350 colunas e 57275 linhas

# %% [markdown]
# ## Passo 2: Agregar Colunas por Prazo
# Precisamos reduzir o número de colunas, o primeiro passo para isso é juntar as colunas que envolvem prazo da seguinte maneira:
#
# - Somar campos entre 0 e 90 dias como `Curto Prazo (CP)`
# - Somar campos entre 90 e 365 dias como `Médio Prazo (MP)`
# - Somar campos acima de 365 dias como `Longo Prazo (LP)`

# %%
_Inadimplentes_181_360_Dias', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_361_720_Dias', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_721_1080_Dias', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_Acima_1080_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_1_30_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_31_60_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_61_90_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_91_120_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_121_150_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_151_180_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_181_360_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_361_720_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_721_1080_Dias', 'Carteira_Direitos_Sem_Aquisicao_Pagos_Acima_1080_Dias', 'Liquidez_Ate_30_Dias', 'Liquidez_Ate_60_Dias', 'Liquidez_Ate_90_Dias', 'Liquidez_Ate_180_Dias', 'Liquidez_Ate_360_Dias', 'Liquidez_Acima_360_Dias']
df.drop(agg_cols_to_drop, axis=1, inplace=True)
step_2_posttreat_col_count = len(df.columns)

print(f"Dropamos {step_2_pretreat_col_count - step_2_posttreat_col_count} colunas")
print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Dropamos 45 colunas
# Agora temos 305 colunas e 57275 linhas

# %% [markdown]
# # Passo 3: Dropas colunas onde todos os valores são iguais

# %%
# Dropar Colunas onde todos os valores são iguais
nunique = df.nunique()
cols_to_drop = nunique[nunique == 1].index

print(f"Dropando {len(cols_to_drop)} colunas onde todos os valores são iguais: ")
print(cols_to_drop)
df = df.drop(cols_to_drop, axis=1)

print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Dropando 15 colunas onde todos os valores são iguais:
# Index(['Ativo_Direitos_Sem_Aquisicao_Creditos_Performar',
#        'Ativo_Direitos_Sem_Aquisicao_Creditos_Empresas_Recuperacao',
#        'Ativo_Direitos_Sem_Aquisicao_Creditos_Receitas_Publicas',
#        'Ativo_Direitos_Sem_Aquisicao_Creditos_Fator_Risco',
#        'Ativo_Coberturas_Prestadas', 'Carteira_Creditos_Tributarios',
#        'Carteira_Royalties', 'Taxas_Titulos_Federais_Juros_Venda_Minina',
#        'Taxas_Titulos_Federais_Juros_Venda_Maxima',
#        'Taxas_CDB_Desconto_Venda_Minina',
#        'Taxas_CDB_Desconto_Venda_Media_Ponderada',
#        'Taxas_CDB_Desconto_Venda_Maxima', 'Taxas_CDB_Juros_Venda_Minina',
#        'Taxas_CDB_Juros_Venda_Media_Ponderada',
#        'Taxas_CDB_Juros_Venda_Maxima'],
#       dtype='object')
# Agora temos 290 colunas e 57275 linhas

# %% [markdown]
# # Passo 4: Somar outros ativos em uma coluna resumida
# Aqui vamos somar as seguintas colunas em `Ativo_Outros`
#
# - `Ativo_Valores_Mobiliarios`
# - `Ativo_Titulos_Federais`
# - `Ativo_CDB`
# - `Ativo_Operacoes_Compromissadas`
# - `Ativo_Outros_Ativos_Renda_Fixa`
# - `Ativo_Cotas_FIDC`
# - `Ativo_Warrants`
# - `Ativo_Posicao_Derivativos`
# - `Ativo_Mercado_Termo`
# - `Ativo_Mercado_Opcoes`
# - `Ativo_Mercado_Futuro`
# - `Ativo_Diferencial_Swap`
# - `Ativo_Depositos_Margem`

# %%
# Vamos somar outros ativos
ativos_drop = ["Ativo_Valores_Mobiliarios", "Ativo_Titulos_Federais", "Ativo_CDB", "Ativo_Operacoes_Compromissadas", "Ativo_Outros_Ativos_Renda_Fixa", "Ativo_Cotas_FIDC", "Ativo_Warrants", "Ativo_Posicao_Derivativos", "Ativo_Mercado_Termo", "Ativo_Mercado_Opcoes", "Ativo_Mercado_Futuro", "Ativo_Diferencial_Swap", "Ativo_Depositos_Margem", "Ativo_Debentures", "Ativo_CRI", "Ativo_Notas_Promissorias", "Ativo_Letras Financeiras", "Ativo_Cotas_Fundos_ICVM_555", "Ativo_Outros_Valores_Mobiliarios", "Ativo_Cotas_FIDC_NP", "Ativo_Provisao_Debentures_CRI_NP_LF", "Ativo_Provisao_Cotas_FIDC", "Ativo_Provisao_Outros_Ativos"]

for ativo in ativos_drop:
  df["Ativo_Outros"] = df["Ativo_Outros"] +  df[ativo]

df = df.drop(ativos_drop, axis=1)

print(f"Dropamos {len(ativos_drop)} colunas")
print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Dropamos 23 colunas
# Agora temos 267 colunas e 57275 linhas

# %% [markdown]
# # Passo 5: Criar uma coluna de `Provisao`

# %%
df["Provisao"] = df["Ativo_Direitos_Aquisicao_Provisao_Reducao"] + df["Ativo_Direitos_Sem_Aquisicao_Provisao_Reducao"]
print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Agora temos 268 colunas e 57275 linhas

# %% [markdown]
# # Manter apenas as colunas selecionadas

# %%
columns_to_keep = ["Data_Competencia", "CNPJ", 'Nome_Fundo', "CNPJ_Administrador", "Forma_Condominio", "Patrimonio_Liquido", "Carteira_Direitos_Aquisicao_Inadimplentes_CP", "Carteira_Direitos_Aquisicao_Inadimplentes_MP", "Carteira_Direitos_Aquisicao_Inadimplentes_LP", "Carteira_Direitos_Sem_Aquisicao_Inadimplentes_CP", "Carteira_Direitos_Sem_Aquisicao_Inadimplentes_MP", "Carteira_Direitos_Sem_Aquisicao_Inadimplentes_LP", "Liquidez_CP", "Liquidez_MP", "Liquidez_LP", "Carteira_Financeiro", "Provisao", "Quantidade_Cotas_Senior", "Valor_Cota_Senior", "Rentabilidade_Senior", "Valor_Total_Captado_Senior", "Valor_Total_Resgates_Senior", "Valor_A_Pagar_Senior", "Quantidade_Cotas_A_Resgatar_Senior", "Valor_Amortizado_Cota_Senior", "Valor_Total_Amortizacao_Senior", "Desempenho_Esperado_Senior", "Desempenho_Realizado_Senior", "Quantidade_Cotas_Subordinada", "Valor_Cota_Subordinada", "Rentabilidade_Subordinada", "Valor_Total_Captado_Subordinada", "Valor_Total_Resgates_Subordinada", "Valor_A_Pagar_Subordinada", "Quantidade_Cotas_A_Resgatar_Subordinada", "Valor_Amortizado_Cota_Subordinada", "Valor_Total_Amortizacao_Subordinada", "Desempenho_Esperado_Subordinada", "Desempenho_Realizado_Subordinada"]
df = df[columns_to_keep]

print(f"Agora temos {len(df.columns)} colunas e {len(df.index)} linhas")
# Out:
# Agora temos 39 colunas e 57275 linhas

# %% [markdown]
# # Retirar linhas liquidadas, ou enviadas erradas
#
# Se essa colunas tiverem com valor igual a 0 o fundo está liquidado, ou o informe mensal foi enviado errado
#
# - `Patrimonio_Liquido`
# - `Carteira_Direitos_Aquisicao_Inadimplentes_CP`
# - `Carteira_Direitos_Aquisicao_Inadimplentes_MP`
# - `Carteira_Direitos_Aquisicao_Inadimplentes_LP`
# - `Carteira_Direitos_Sem_Aquisicao_Inadimplentes_CP`
# - `Carteira_Direitos_Sem_Aquisicao_Inadimplentes_MP`
# - `Carteira_Direitos_Sem_Aquisicao_Inadimplentes_LP`
# - `Liquidez_CP`
# - `Liquidez_MP`
# - `Liquidez_LP`
# - `Carteira_Financeiro`
# - `Provisao`
# - `Quantidade_Cotas_Senior`
# - `Valor_Cota_Senior`
# - `Rentabilidade_Senior`
# - `Valor_Total_Captado_Senior`
# - `Valor_Total_Resgates_Senior`
# - `Valor_A_Pagar_Senior`
# - `Quantidade_Cotas_A_Resgatar_Senior`
# - `Valor_Amortizado_Cota_Senior`
# - `Valor_Total_Amortizacao_Senior`
# - `Desempenho_Esperado_Senior`
# - `Desempenho_Realizado_Senior`
# - `Quantidade_Cotas_Subordinada`
# - `Valor_Cota_Subordinada`
# - `Rentabilidade_Subordinada`
# - `Valor_Total_Captado_Subordinada`
# - `Valor_Total_Resgates_Subordinada`
# - `Valor_A_Pagar_Subordinada`
# - `Quantidade_Cotas_A_Resgatar_Subordinada`
# - `Valor_Amortizado_Cota_Subordinada`
# - `Valor_Total_Amortizacao_Subordinada`
# - `Desempenho_Esperado_Subordinada`
# - `Desempenho_Realizado_Subordinada`

# %%
colunas = df.columns.tolist()
colunas_padrao = ['CNPJ', 'Nome_Fundo', 'Data_Competencia', 'CNPJ_Administrador', 'Forma_Condominio']
for colunasP in colunas_padrao:
  colunas.remove(colunasP)
colunas
# Out:
# ['Patrimonio_Liquido',
#  'Carteira_Direitos_Aquisicao_Inadimplentes_CP',
#  'Carteira_Direitos_Aquisicao_Inadimplentes_MP',
#  'Carteira_Direitos_Aquisicao_Inadimplentes_LP',
#  'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_CP',
#  'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_MP',
#  'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_LP',
#  'Liquidez_CP',
#  'Liquidez_MP',
#  'Liquidez_LP',
#  'Carteira_Financeiro',
#  'Provisao',
#  'Quantidade_Cotas_Senior',
#  'Valor_Cota_Senior',
#  'Rentabilidade_Senior',
#  'Valor_Total_Captado_Senior',
#  'Valor_Total_Resgates_Senior',
#  'Valor_A_Pagar_Senior',
#  'Quantidade_Cotas_A_Resgatar_Senior',
#  'Valor_Amortizado_Cota_Senior',
#  'Valor_Total_Amortizacao_Senior',
#  'Desempenho_Esperado_Senior',
#  'Desempenho_Realizado_Senior',
#  'Quantidade_Cotas_Subordinada',
#  'Valor_Cota_Subordinada',
#  'Rentabilidade_Subordinada',
#  'Valor_Total_Captado_Subordinada',
#  'Valor_Total_Resgates_Subordinada',
#  'Valor_A_Pagar_Subordinada',
#  'Quantidade_Cotas_A_Resgatar_Subordinada',
#  'Valor_Amortizado_Cota_Subordinada',
#  'Valor_Total_Amortizacao_Subordinada',
#  'Desempenho_Esperado_Subordinada',
#  'Desempenho_Realizado_Subordinada']

# %%
linhas_liquidadas = df[df[colunas].eq(0).all(axis=1)]
linhas_liquidadas
# Out:
#       Data_Competencia            CNPJ  \
# 166         2020-11-30  31809006000138
# 340         2020-11-30  29883381000186
# 341         2020-11-30  31151932000169
# 342         2020-11-30  29492796000129
# 344         2020-11-30  28472373000184
# ...                ...             ...
# 47020       2019-03-31  29044084000147
# 47518       2019-04-30  22483823000158
# 54896       2020-07-31  17288447000100
# 57152       2020-09-30  26648825000100
# 57158       2020-09-30  21862216000136
#
#                                               Nome_Fundo  CNPJ_Administrador  \
# 166    FUNDO DE INVES TIMENTO EM DIREITOS CREDITORIOS...        1.348679e+13
# 340    FIDC RECEBÍVEIS ENEVA - FUNDO DE INVESTIMENTOS...        2.261050e+13
# 341    FIDC VX XXV - FUNDO DE INVESTIMENTOS EM DIREIT...        2.261050e+13
# 342    ASIMOV FUNDO DE INVESTIMENTO EM COTAS DE FUNDO...        3.317692e+12
# 344    FIDC ENEVA RECEBÍVEIS - FUNDO DE INVESTIMENTOS...        2.261050e+13
# ...                                                  ...                 ...
# 47020  FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS ...        2.201501e+12
# 47518  DRIVER BRASIL THREE BANCO VOLKSWAGEN FIDC FINA...        6.667000e+10
# 54896  MULTI7 FUNDO DE INVESTIMENTO EM DIREITOS CREDI...        6.228539e+13
# 57152  ÁTRIO CREDITOO FUNDO DE INVESTIMENTO EM DIREIT...        6.228539e+13
# 57158  GESTOR TRUST FUNDO DE INVESTIMENTO EM DIREITOS...        3.751794e+12
#
#       Forma_Condominio  Patrimonio_Liquido  \
# 166            FECHADO                 0.0
# 340            FECHADO                 0.0
# 341            FECHADO                 0.0
# 342            FECHADO                 0.0
# 344            FECHADO                 0.0
# ...                ...                 ...
# 47020          FECHADO                 0.0
# 47518          FECHADO                 0.0
# 54896          FECHADO                 0.0
# 57152          FECHADO                 0.0
# 57158           ABERTO                 0.0
#
#        Carteira_Direitos_Aquisicao_Inadimplentes_CP  \
# 166                                             0.0
# 340                                             0.0
# 341                                             0.0
# 342                                             0.0
# 344                                             0.0
# ...                                             ...
# 47020                                           0.0
# 47518                                           0.0
# 54896                                           0.0
# 57152                                           0.0
# 57158                                           0.0
#
#        Carteira_Direitos_Aquisicao_Inadimplentes_MP  \
# 166                                             0.0
# 340                                             0.0
# 341                                             0.0
# 342                                             0.0
# 344                                             0.0
# ...                                             ...
# 47020                                           0.0
# 47518                                           0.0
# 54896                                           0.0
# 57152                                           0.0
# 57158                                           0.0
#
#        Carteira_Direitos_Aquisicao_Inadimplentes_LP  \
# 166                                             0.0
# 340                                             0.0
# 341                                             0.0
# 342                                             0.0
# 344                                             0.0
# ...                                             ...
# 47020                                           0.0
# 47518                                           0.0
# 54896                                           0.0
# 57152                                           0.0
# 57158                                           0.0
#
#        Carteira_Direitos_Sem_Aquisicao_Inadimplentes_CP  ...  \
# 166                                                 0.0  ...
# 340                                                 0.0  ...
# 341                                                 0.0  ...
# 342                                                 0.0  ...
# 344                                                 0.0  ...
# ...                                                 ...  ...
# 47020                                               0.0  ...
# 47518                                               0.0  ...
# 54896                                               0.0  ...
# 57152                                               0.0  ...
# 57158                                               0.0  ...
#
#        Valor_Cota_Subordinada  Rentabilidade_Subordinada  \
# 166                       0.0                        0.0
# 340                       0.0                        0.0
# 341                       0.0                        0.0
# 342                       0.0                        0.0
# 344                       0.0                        0.0
# ...                       ...                        ...
# 47020                     0.0                        0.0
# 47518                     0.0                        0.0
# 54896                     0.0                        0.0
# 57152                     0.0                        0.0
# 57158                     0.0                        0.0
#
#        Valor_Total_Captado_Subordinada  Valor_Total_Resgates_Subordinada  \
# 166                                0.0                               0.0
# 340                                0.0                               0.0
# 341                                0.0                               0.0
# 342                                0.0                               0.0
# 344                                0.0                               0.0
# ...                                ...                               ...
# 47020                              0.0                               0.0
# 47518                              0.0                               0.0
# 54896                              0.0                               0.0
# 57152                              0.0                               0.0
# 57158                              0.0                               0.0
#
#        Valor_A_Pagar_Subordinada  Quantidade_Cotas_A_Resgatar_Subordinada  \
# 166                          0.0                                      0.0
# 340                          0.0                                      0.0
# 341                          0.0                                      0.0
# 342                          0.0                                      0.0
# 344                          0.0                                      0.0
# ...                          ...                                      ...
# 47020                        0.0                                      0.0
# 47518                        0.0                                      0.0
# 54896                        0.0                                      0.0
# 57152                        0.0                                      0.0
# 57158                        0.0                                      0.0
#
#        Valor_Amortizado_Cota_Subordinada  Valor_Total_Amortizacao_Subordinada  \
# 166                                  0.0                                  0.0
# 340                                  0.0                                  0.0
# 341                                  0.0                                  0.0
# 342                                  0.0                                  0.0
# 344                                  0.0                                  0.0
# ...                                  ...                                  ...
# 47020                                0.0                                  0.0
# 47518                                0.0                                  0.0
# 54896                                0.0                                  0.0
# 57152                                0.0                                  0.0
# 57158                                0.0                                  0.0
#
#        Desempenho_Esperado_Subordinada  Desempenho_Realizado_Subordinada
# 166                                0.0                               0.0
# 340                                0.0                               0.0
# 341                                0.0                               0.0
# 342                                0.0                               0.0
# 344                                0.0                               0.0
# ...                                ...                               ...
# 47020                              0.0                               0.0
# 47518                              0.0                               0.0
# 54896                              0.0                               0.0
# 57152                              0.0                               0.0
# 57158                              0.0                               0.0
#
# [593 rows x 39 columns]

# %%
df = df.drop(linhas_liquidadas.index)

# %% [markdown]
# ### Substituindo valores Nulos

# %%
colunas = ['Carteira_Direitos_Aquisicao_Inadimplentes_CP', 'Carteira_Direitos_Aquisicao_Inadimplentes_MP', 'Carteira_Direitos_Aquisicao_Inadimplentes_LP', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_CP', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_MP', 'Carteira_Direitos_Sem_Aquisicao_Inadimplentes_LP', 'Liquidez_CP', 'Liquidez_MP', 'Liquidez_LP']
for coluna in colunas:
  df[coluna] = df[coluna].fillna(0)

# %% [markdown]
# # Treinando Modelo

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.metrics import precision_score, roc_curve, auc, confusion_matrix, classification_report
import xgboost as xgb
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from cuml.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, roc_auc_score, recall_score

# %%
models = [
    ('Random Forest', RandomForestClassifier(n_estimators=1000)),
    ('SVM', SVC()),
    ('Logistic Regression', LogisticRegression()),
    ('Bagging Classifier', BaggingClassifier()),
    ('AdaBoost Classifier', AdaBoostClassifier()),
    ('Gradient Boosting', GradientBoostingClassifier())
]

# %% [markdown]
# # Gerar dados sintéticos

# %%
synthetic_data_realistic = pd.read_csv('synthetic_data_realistic.csv', encoding='latin1')

# %%
nomes = ['FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS INDIGO BARTER', 'FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS BRAVA CHALLENGE', 'CREDIHOME FUNDO DE INVESTIMENTO EM DIREITOS CREDITORIOS', 'RUBI FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS MULTISETORIAL', 'FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS BULLLA', 'LS INTERBANK FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS', 'TURQUESA - FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS']
def analisa_nomes(valor):
  for nome in nomes:
    if valor == nome:
      return 1
    else:
      return 0

df['FIDCs_em_alerta'] = df.Nome_Fundo.apply(analisa_nomes)
df['FIDCs_em_alerta'].value_counts()
# Out:
# 0    56636
# 1       46
# Name: FIDCs_em_alerta, dtype: int64

# %%
df = df.dropna(subset=['Forma_Condominio'])

# %%
df.Forma_Condominio.unique()
# Out:
# array(['ABERTO', 'FECHADO'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
var_mod =['Forma_Condominio']
le = LabelEncoder()
for i in var_mod:
  df[i] = le.fit_transform(df[i])

# %%
df.Forma_Condominio.unique()
# Out:
# array([0, 1])

# %%
df = df.dropna(axis=0)

# %%
df.shape
# Out:
# (53462, 40)

# %% [markdown]
# ### Fazendo UnderSampling

# %%
synthetic_data_realistic.FIDCs_em_alerta.value_counts()
# Out:
# 0    34756
# 1    15244
# Name: FIDCs_em_alerta, dtype: int64

# %% [markdown]
# Separando os fundos que quebraram e não quebraram

# %%
fundos_Nao_Quebraram_Sinteticos = synthetic_data_realistic.loc[synthetic_data_realistic.FIDCs_em_alerta == 0]
fundos_Quebraram_Sinteticos = synthetic_data_realistic.loc[synthetic_data_realistic.FIDCs_em_alerta == 1]

# %% [markdown]
# Deixando os fundos que quebraram e não quebraram com o mesmo tamanho

# %%
fundos_Nao_Quebraram_Sinteticos = fundos_Nao_Quebraram_Sinteticos.sample(n=15244, random_state=42)

# %% [markdown]
# Juntando eles em um DataFrame

# %%
synthetic_data_realistic = pd.concat([fundos_Nao_Quebraram_Sinteticos, fundos_Quebraram_Sinteticos], axis=0)

# %%
synthetic_data_realistic.shape
# Out:
# (30488, 40)

# %%
synthetic_data_realistic.FIDCs_em_alerta.value_counts()
# Out:
# 0    15244
# 1    15244
# Name: FIDCs_em_alerta, dtype: int64

# %% [markdown]
# # Avaliando as Features utilizadas

# %%
colunas_para_converter = synthetic_data_realistic.select_dtypes(include=['float64']).columns

# %%
for coluna in colunas_para_converter:
    synthetic_data_realistic[coluna] = synthetic_data_realistic[coluna].astype('float32')
    df[coluna] = df[coluna].astype('float32')

# %%
X_train = synthetic_data_realistic.drop(['FIDCs_em_alerta', 'Nome_Fundo', 'CNPJ', 'CNPJ_Administrador', 'Data_Competencia'], axis=1)
y_train = synthetic_data_realistic.FIDCs_em_alerta

X_test = df.drop(['FIDCs_em_alerta', 'Nome_Fundo', 'CNPJ', 'CNPJ_Administrador', 'Data_Competencia'], axis=1)
y_test = df.FIDCs_em_alerta

# %%
feature_names = X_train.columns

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = np.float32(X_train)
y_train = np.float32(y_train)
X_test = np.float32(X_test)
y_test = np.float32(y_test)

# %%
from sklearn.inspection import permutation_importance

# %%
from sklearn.metrics import mean_absolute_error

# %%
feature_names[10]
# Out:
# 'Liquidez_LP'

# %%
model = RandomForestClassifier(n_estimators=1000, random_state=42, n_streams=1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
precision = precision_score(y_test, y_pred)

precision_original = precision_score(y_test, y_pred)

recall_original = recall_score(y_test, y_pred)
recall_original_2 = recall_original**2

score_original = precision_original * recall_original_2
print(score_original)

print(f'Precision: {precision}')
print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{confusion}')
print(f'Classification Report:\n{classification_rep}')


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plote a curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
print('=' * 70)
print('=' * 70)
# Out:
# 0.007453013609850939
# Precision: 0.007453013609850939
# Accuracy: 0.8854139388724702
# Confusion Matrix:
# [[47290  6126]
#  [    0    46]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94     53416
#          1.0       0.01      1.00      0.01        46
#
#     accuracy                           0.89     53462
#    macro avg       0.50      0.94      0.48     53462
# weighted avg       1.00      0.89      0.94     53462
# ======================================================================
# ======================================================================

# %%
# model = RandomForestClassifier(n_estimators=1000, random_state=42, n_streams=1)
# model.fit(X_train, y_train)

# # Calcule o ROC AUC score no conjunto de teste original
# y_pred = model.predict(X_test)

# precision_original = precision_score(y_test, y_pred)


# score_original = precision_original
# print(score_original)

# # Inicialize um array para armazenar as pontuações de importância de features
# feature_importances = np.zeros(X_train.shape[1])

# # Faça a permutação de cada feature e calcule o ROC AUC score
# for i in range(X_train.shape[1]):
#     X_test_permuted = X_test.copy()
#     np.random.shuffle(X_test_permuted[:, i])  # Permute a feature i
#     y_pred_permuted = model.predict(X_test_permuted)

#     precision_permuted = precision_score(y_test, y_pred_permuted)

#     recall_permuted = recall_score(y_test, y_pred_permuted)

#     if recall_permuted < 1:
#       score_permuted = score_original
#     else:
#       score_permuted = precision_permuted

#     feature_importances[i] = score_original - score_permuted

# # Ordene as features com base nas pontuações de importância
# sorted_feature_indices = np.argsort(feature_importances)[::-1]

# # Imprima as features em ordem decrescente de importância
# # for idx in sorted_feature_indices:
# #     print(f'Feature {idx}: {feature_importances[idx]}')

# # plt.bar(range(X_test.shape[1]),feature_importances[sorted_feature_indices])
# # plt.xticks(range(X_test.shape[1]), feature_names[sorted_feature_indices], rotation=90)
# # plt.xlabel('Features')
# # plt.ylabel('Importância por Permutação')
# # plt.show()

# for i in sorted_feature_indices:
#     print(f'{feature_names[i]:20} {feature_importances[i]:.4f}')
# # Remova as features menos importantes
# limite_importancia = -0.0007
# features_to_remove = [i for i in sorted_feature_indices if feature_importances[i] < limite_importancia]
# # X_train.drop(features_to_remove, axis=1, inplace=True)
# # X_test.drop(features_to_remove, axis=1, inplace=True)
# print(features_to_remove)
# X_test_filtered = np.delete(X_test, features_to_remove, axis=1)

# %%
# model = RandomForestClassifier(n_estimators=1000, random_state=42, n_streams=1)
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test_filtered)

# accuracy = accuracy_score(y_test, y_pred)
# confusion = confusion_matrix(y_test, y_pred)
# classification_rep = classification_report(y_test, y_pred)
# precision = precision_score(y_test, y_pred)

# precision_original = precision_score(y_test, y_pred)

# recall_original = recall_score(y_test, y_pred)
# recall_original_2 = recall_original**1

# score_original = precision_original * recall_original_2
# print(score_original)

# print(f'Precision: {precision}')
# print(f'Accuracy: {accuracy}')
# print(f'Confusion Matrix:\n{confusion}')
# print(f'Classification Report:\n{classification_rep}')


# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# # Plote a curva ROC
# plt.figure()
# plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = {:.2f})'.format(roc_auc))
# plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('Taxa de Falso Positivo')
# plt.ylabel('Taxa de Verdadeiro Positivo')
# plt.title('Curva ROC')
# plt.legend(loc="lower right")
# plt.show()
# print('=' * 70)
# print('=' * 70)

# %%
# rfc = RandomForestClassifier(n_estimators=1000, random_state=42, n_streams=1)  # Você pode ajustar o número de árvores (n_estimators)

# # Treine o modelo no conjunto de treinamento
# rfc.fit(X_train, y_train)

# # Calcula a importância das features por permutação
# perm_importance = permutation_importance(rfc, X_test, y_test)

# # Plote a importância das features por permutação
# sorted_idx = perm_importance.importances_mean.argsort()[::-1]

# y_pred = rfc.predict(X_test)
# mse = mean_squared_error(y_test, y_pred)
# print(f'MSE: {mse}')
# plt.bar(range(X_test.shape[1]), perm_importance.importances_mean[sorted_idx])
# plt.xticks(range(X_test.shape[1]), feature_names[sorted_idx], rotation=90)
# plt.xlabel('Features')
# plt.ylabel('Importância por Permutação')
# plt.show()

# %%
# rfc = RandomForestClassifier(n_estimators=1000, random_state=42, n_streams=1)

# feature_importance = perm_importance.importances_mean


# # Identifique as características a serem removidas
# features_to_remove = []
# for i, importance in enumerate(feature_importance):
#   if importance < -0.01:
#     features_to_remove.append(i)

# # Remova as características do conjunto de teste
# X_test_filtered = np.delete(X_test, features_to_remove, axis=1)

# rfc.fit(X_train, y_train)

# # Faça previsões no conjunto de teste filtrado
# y_pred = rfc.predict(X_test_filtered)

# # Avalie o desempenho com o novo modelo
# mse_filtered = mean_squared_error(y_test, y_pred)
# accuracy = accuracy_score(y_test, y_pred)

# print(f'Acurácia: {accuracy}')
# print(f'MSE com características filtradas: {mse_filtered}')
# print("==" * 50)

# %%
pred = pd.DataFrame(y_pred)

# %%
pred.describe()
# Out:
#                   0
# count  53462.000000
# mean       0.115446
# std        0.319563
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
rfc = RandomForestClassifier()
rfc.get_param_names()
# Out:
# ['handle',
#  'verbose',
#  'output_type',
#  'n_estimators',
#  'max_depth',
#  'handle',
#  'max_features',
#  'n_bins',
#  'split_criterion',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_impurity_decrease',
#  'bootstrap',
#  'verbose',
#  'max_samples',
#  'max_leaves',
#  'accuracy_metric',
#  'max_batch_size',
#  'n_streams',
#  'dtype',
#  'output_type',
#  'min_weight_fraction_leaf',
#  'n_jobs',
#  'max_leaf_nodes',
#  'min_impurity_split',
#  'oob_score',
#  'random_state',
#  'warm_start',
#  'class_weight',
#  'criterion']

# %%
import optuna

# %%
def objective(trial):
  n_estimators = trial.suggest_int('n_estimators', 10, 1000)
  split_criterion = trial.suggest_int('split_criterion', 0, 1)
  bootstrap = trial.suggest_categorical("bootstrap", [True, False])
  max_samples = trial.suggest_float('max_samples', 0, 1)
  max_depth = trial.suggest_int('max_depth', 1, 10000)
  max_leaves = trial.suggest_int('max_leaves', -1, 10000)
  max_features = trial.suggest_float('max_features', 0, 1)
  n_bins = trial.suggest_int('n_bins', 1, 1024)
  min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.001, 10000, log=True)
  min_samples_split = trial.suggest_float('min_samples_split', 0.001, 10000, log=True)
  min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.001, 10000, log=True)
  random_state = trial.suggest_int('random_state', 1, 10000)
  if max_leaves == 0:
    max_leaves = 1

  if bootstrap == False:
    model = RandomForestClassifier(n_streams=1, n_estimators=n_estimators, split_criterion=split_criterion, bootstrap=bootstrap, max_depth=max_depth, max_leaves=max_leaves, max_features=max_features, n_bins=n_bins, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split, min_impurity_decrease=min_impurity_decrease, random_state=random_state)
  else:
    model = RandomForestClassifier(n_streams=1, n_estimators=n_estimators, split_criterion=split_criterion, bootstrap=bootstrap, max_samples=max_samples, max_depth=max_depth, max_leaves=max_leaves, max_features=max_features, n_bins=n_bins, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split, min_impurity_decrease=min_impurity_decrease, random_state=random_state)


  model.fit(X_train, y_train)

  y_pred = model.predict(X_test)

  precision = precision_score(y_test, y_pred, zero_division=0)

  recall = recall_score(y_test, y_pred)

  if recall < 1:
    recall = 0

  score = precision * recall

  return score

# %%
study = optuna.create_study(
    direction='maximize',
    sampler=optuna.samplers.TPESampler(),
    pruner=optuna.pruners.HyperbandPruner()
)
study.optimize(objective, n_trials=10000, n_jobs=-1)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.18584883706691735, 'max_depth': 8225, 'max_leaves': 4963, 'max_features': 0.3212091921123319, 'n_bins': 785, 'min_samples_leaf': 319.1057883819003, 'min_samples_split': 0.03748320865744619, 'min_impurity_decrease': 0.001756065437823531}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:05,729] Trial 5067 finished with value: 0.0 and parameters: {'n_estimators': 601, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.18399963662318952, 'max_depth': 8197, 'max_leaves': 4922, 'max_features': 0.3861508980036757, 'n_bins': 784, 'min_samples_leaf': 1443.8898992069498, 'min_samples_split': 0.03660679917534653, 'min_impurity_decrease': 1.0234065217867787}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:16,609] Trial 5068 finished with value: 0.0 and parameters: {'n_estimators': 629, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.4677515785309526, 'max_depth': 8153, 'max_leaves': 4911, 'max_features': 0.30054055260839574, 'n_bins': 780, 'min_samples_leaf': 0.0014083966484256189, 'min_samples_split': 0.03534583480694845, 'min_impurity_decrease': 0.0016894537529539668}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:23,580] Trial 5069 finished with value: 0.0 and parameters: {'n_estimators': 613, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.18505709435252266, 'max_depth': 8602, 'max_leaves': 4973, 'max_features': 0.2673479028313661, 'n_bins': 826, 'min_samples_leaf': 0.0013990061095530315, 'min_samples_split': 42.044640036020134, 'min_impurity_decrease': 484.1374814575776}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:23,812] Trial 5070 finished with value: 0.0 and parameters: {'n_estimators': 608, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.18371075744367155, 'max_depth': 8212, 'max_leaves': 4885, 'max_features': 0.25977571117299214, 'n_bins': 788, 'min_samples_leaf': 0.0013828463750835149, 'min_samples_split': 3.2427419479971302, 'min_impurity_decrease': 0.0010021886464447248}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:24,239] Trial 5071 finished with value: 0.0 and parameters: {'n_estimators': 611, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.18205012465487277, 'max_depth': 8638, 'max_leaves': 4830, 'max_features': 0.59757489175336, 'n_bins': 824, 'min_samples_leaf': 0.0012908560427276699, 'min_samples_split': 0.15857500560947232, 'min_impurity_decrease': 2.5501846329335724}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:33,086] Trial 5072 finished with value: 0.0 and parameters: {'n_estimators': 599, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.1537697896298122, 'max_depth': 8190, 'max_leaves': 4843, 'max_features': 0.2681673531365949, 'n_bins': 828, 'min_samples_leaf': 0.0013298514637729976, 'min_samples_split': 0.059611342093854075, 'min_impurity_decrease': 0.004658415507840864}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:50,522] Trial 5073 finished with value: 0.0 and parameters: {'n_estimators': 594, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.17969941905208983, 'max_depth': 8637, 'max_leaves': 4884, 'max_features': 0.26524329433284816, 'n_bins': 830, 'min_samples_leaf': 0.0013350539742104388, 'min_samples_split': 20.309629530856352, 'min_impurity_decrease': 13.084344191998445}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:51,754] Trial 5074 finished with value: 0.0 and parameters: {'n_estimators': 596, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.15359625521653092, 'max_depth': 8647, 'max_leaves': 4835, 'max_features': 0.5120306358460258, 'n_bins': 823, 'min_samples_leaf': 0.002096215231799042, 'min_samples_split': 0.0036967329615368444, 'min_impurity_decrease': 186.2985382426449}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:11:52,240] Trial 5075 finished with value: 0.0 and parameters: {'n_estimators': 601, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.31260846074825455, 'max_depth': 3029, 'max_leaves': 4886, 'max_features': 0.26892682255296513, 'n_bins': 798, 'min_samples_leaf': 1.161632770486466, 'min_samples_split': 0.05947231137548473, 'min_impurity_decrease': 0.00389302807828803}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10
. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:00,941] Trial 5086 finished with value: 0.0008604242265534398 and parameters: {'n_estimators': 588, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.7614665531970077, 'max_depth': 8819, 'max_leaves': 5454, 'max_features': 0.19981868571133382, 'n_bins': 718, 'min_samples_leaf': 0.550539876067199, 'min_samples_split': 17.014701748991047, 'min_impurity_decrease': 8.14862086019026}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:01,037] Trial 5085 finished with value: 0.0008604242265534398 and parameters: {'n_estimators': 669, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.7501323318922648, 'max_depth': 8481, 'max_leaves': 4643, 'max_features': 0.22930134735880683, 'n_bins': 716, 'min_samples_leaf': 0.002078142650098549, 'min_samples_split': 0.008451460410511804, 'min_impurity_decrease': 544.1352986707805}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:07,806] Trial 5087 finished with value: 0.0 and parameters: {'n_estimators': 665, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.7195727342523145, 'max_depth': 8491, 'max_leaves': 5197, 'max_features': 0.22030301577982628, 'n_bins': 708, 'min_samples_leaf': 0.006370925462936987, 'min_samples_split': 9.40195212986813, 'min_impurity_decrease': 0.0016487414182707063}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:20,424] Trial 5088 finished with value: 0.0 and parameters: {'n_estimators': 679, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0.4494908711504367, 'max_depth': 8814, 'max_leaves': 5636, 'max_features': 0.228255386002139, 'n_bins': 800, 'min_samples_leaf': 70.46793053689713, 'min_samples_split': 0.042956298014307524, 'min_impurity_decrease': 0.0063941806803119085}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:26,542] Trial 5089 finished with value: 0.0 and parameters: {'n_estimators': 585, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.6860802211278582, 'max_depth': 7994, 'max_leaves': 5226, 'max_features': 0.5327544505658061, 'n_bins': 802, 'min_samples_leaf': 0.003688148701295142, 'min_samples_split': 8.49872391386882, 'min_impurity_decrease': 0.005236010043947896}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:27,441] Trial 5090 finished with value: 0.0 and parameters: {'n_estimators': 586, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.7295341733767973, 'max_depth': 8833, 'max_leaves': 5369, 'max_features': 0.23307673504604862, 'n_bins': 799, 'min_samples_leaf': 0.0032228105788867254, 'min_samples_split': 660.6943709186125, 'min_impurity_decrease': 3.804297502244028}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:47,471] Trial 5091 finished with value: 0.0 and parameters: {'n_estimators': 579, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.691041050704387, 'max_depth': 7922, 'max_leaves': 5371, 'max_features': 0.29383393486530496, 'n_bins': 798, 'min_samples_leaf': 0.0036274039335070863, 'min_samples_split': 0.13340043524120518, 'min_impurity_decrease': 0.003851127342405942}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:13:47,743] Trial 5092 finished with value: 0.0 and parameters: {'n_estimators': 573, 'split_criterion': 1, 'bootstrap': True, 'max_samples': 0.32452739928932056, 'max_depth': 8029, 'max_leaves': 5229, 'max_features': 0.6168796218457655, 'n_bins': 805, 'min_samples_leaf': 0.0037500765804530513, 'min_samples_split': 0.01787739603487207, 'min_impurity_decrease': 0.0016283494380981607}. Best is trial 4617 with value: 0.008636875704093128.
# [I 2023-10-03 10:14:00,464] Trial 5093 finished with value: 0.0 and parameters: {'n_estimators': 667, 'split_criterion': 1, 'bootstrap': False, 'max_samples': 0
 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9793575804924642, 'max_depth': 4083, 'max_leaves': 9662, 'max_features': 0.7762975070748974, 'n_bins': 909, 'min_samples_leaf': 0.015163930976881665, 'min_samples_split': 0.004602492062468436, 'min_impurity_decrease': 44.02203894330837}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:08:57,186] Trial 9981 finished with value: 0.0 and parameters: {'n_estimators': 709, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.07531544320815331, 'max_depth': 3952, 'max_leaves': 9546, 'max_features': 0.7801437972105523, 'n_bins': 900, 'min_samples_leaf': 0.013355306759582982, 'min_samples_split': 0.005348388444242979, 'min_impurity_decrease': 0.814190192755321}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:09:26,367] Trial 9983 finished with value: 0.0 and parameters: {'n_estimators': 685, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9434944750323542, 'max_depth': 3997, 'max_leaves': 9270, 'max_features': 0.8172825479784946, 'n_bins': 897, 'min_samples_leaf': 0.029543439078188842, 'min_samples_split': 5033.763820190635, 'min_impurity_decrease': 0.01807240161806491}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:09:28,068] Trial 9984 finished with value: 0.0 and parameters: {'n_estimators': 712, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.996195295067502, 'max_depth': 4188, 'max_leaves': 9574, 'max_features': 0.814453120936581, 'n_bins': 905, 'min_samples_leaf': 0.02512591827714773, 'min_samples_split': 0.00272513614229652, 'min_impurity_decrease': 1803.1414719980257}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:09:54,586] Trial 9985 finished with value: 0.0 and parameters: {'n_estimators': 691, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9736880084320251, 'max_depth': 3753, 'max_leaves': 9480, 'max_features': 0.8167356565688104, 'n_bins': 899, 'min_samples_leaf': 0.02456457789556185, 'min_samples_split': 0.003625248376691888, 'min_impurity_decrease': 0.01898939963373406}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:09:55,144] Trial 9986 finished with value: 0.0 and parameters: {'n_estimators': 699, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9723987801135001, 'max_depth': 3751, 'max_leaves': 9571, 'max_features': 0.8164373629721049, 'n_bins': 918, 'min_samples_leaf': 0.048894135107009885, 'min_samples_split': 164.758771854861, 'min_impurity_decrease': 0.9525692210667047}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:09:55,957] Trial 9987 finished with value: 0.0 and parameters: {'n_estimators': 695, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.927151061342627, 'max_depth': 3767, 'max_leaves': 9336, 'max_features': 0.8176246261754015, 'n_bins': 929, 'min_samples_leaf': 0.02672210917629767, 'min_samples_split': 0.003501548385243217, 'min_impurity_decrease': 0.012123637721413533}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:11,992] Trial 9988 finished with value: 0.0 and parameters: {'n_estimators': 694, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.850859578159596, 'max_depth': 3809, 'max_leaves': 9550, 'max_features': 0.8232648328227928, 'n_bins': 913, 'min_samples_leaf': 917.0334873977803, 'min_samples_split': 30.528019675969848, 'min_impurity_decrease': 0.01306627203147001}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:20,709] Trial 9989 finished with value: 0.0 and parameters: {'n_estimators': 703, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.8831720655656969, 'max_depth': 3726, 'max_leaves': 9572, 'max_features': 0.8152441641257053, 'n_bins': 898, 'min_samples_leaf': 766.2426963885109, 'min_samples_split': 0.003687749141601614, 'min_impurity_decrease': 1.9984373794142385}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:36,286] Trial 9990 finished with value: 0.0 and parameters: {'n_estimators': 693, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9646338941178066, 'max_depth': 3690, 'max_leaves': 9952, 'max_features': 0.8217960274064514, 'n_bins': 915, 'min_samples_leaf': 0.01158165833680104, 'min_samples_split': 0.002494720952248805, 'min_impurity_decrease': 6.664957351370883}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:38,283] Trial 9992 finished with value: 0.0 and parameters: {'n_estimators': 682, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.6984872334134455, 'max_depth': 3771, 'max_leaves': 9248, 'max_features': 0.817917818426597, 'n_bins': 912, 'min_samples_leaf': 0.011359535948563626, 'min_samples_split': 106.85977233719633, 'min_impurity_decrease': 0.02442763462705812}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:39,066] Trial 9991 finished with value: 0.0 and parameters: {'n_estimators': 688, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9200182894797904, 'max_depth': 3725, 'max_leaves': 9889, 'max_features': 0.8148709235545144, 'n_bins': 902, 'min_samples_leaf': 0.011507771907300922, 'min_samples_split': 0.002376212961375564, 'min_impurity_decrease': 0.026675716240883735}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:59,000] Trial 9994 finished with value: 0.0 and parameters: {'n_estimators': 667, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.8874389256703202, 'max_depth': 3695, 'max_leaves': 9525, 'max_features': 0.8155068722913716, 'n_bins': 908, 'min_samples_leaf': 0.011876964162292333, 'min_samples_split': 0.0021110622894799985, 'min_impurity_decrease': 0.010166105008022614}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:10:59,683] Trial 9993 finished with value: 0.0 and parameters: {'n_estimators': 680, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.6697550025450729, 'max_depth': 3881, 'max_leaves': 9925, 'max_features': 0.7468530377895665, 'n_bins': 898, 'min_samples_leaf': 0.012210278620113197, 'min_samples_split': 0.0024894548958017157, 'min_impurity_decrease': 18.766172683885486}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:11:17,969] Trial 9995 finished with value: 0.0 and parameters: {'n_estimators': 691, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.7860038211781267, 'max_depth': 4337, 'max_leaves': 9865, 'max_features': 0.7685510349077805, 'n_bins': 921, 'min_samples_leaf': 0.02098162218786356, 'min_samples_split': 0.20437746464157575, 'min_impurity_decrease': 0.01456533251251942}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:11:26,396] Trial 9996 finished with value: 0.0 and parameters: {'n_estimators': 670, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9493913618908676, 'max_depth': 4200, 'max_leaves': 9654, 'max_features': 0.7655191426486977, 'n_bins': 926, 'min_samples_leaf': 0.01906290596421712, 'min_samples_split': 3.1805031965962036, 'min_impurity_decrease': 0.3567781002614266}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:11:41,414] Trial 9998 finished with value: 0.0 and parameters: {'n_estimators': 687, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.36690033164585406, 'max_depth': 4114, 'max_leaves': 9839, 'max_features': 0.7756735516177395, 'n_bins': 927, 'min_samples_leaf': 0.03615456379480399, 'min_samples_split': 0.14003321623702325, 'min_impurity_decrease': 0.015541733377669155}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:11:41,435] Trial 9997 finished with value: 0.0 and parameters: {'n_estimators': 689, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.8642168033664066, 'max_depth': 4198, 'max_leaves': 9410, 'max_features': 0.7696555399121975, 'n_bins': 930, 'min_samples_leaf': 166.9061441094431, 'min_samples_split': 1.1359558727097852, 'min_impurity_decrease': 0.006007942408713106}. Best is trial 9287 with value: 0.010926365795724466.
# [I 2023-10-03 23:11:41,440] Trial 9999 finished with value: 0.0 and parameters: {'n_estimators': 686, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9985026324184989, 'max_depth': 4106, 'max_leaves': 9685, 'max_features': 0.795247735822064, 'n_bins': 925, 'min_samples_leaf': 0.19964212891657449, 'min_samples_split': 0.0016893847180623897, 'min_impurity_decrease': 0.010091524471441501}. Best is trial 9287 with value: 0.010926365795724466.

# %%
best_params = study.best_params
best_score = study.best_value
print('Melhor hyperparâmetros: ', best_params)
print('melhor Score: ', best_score)
# Out:
# Melhor hyperparâmetros:  {'n_estimators': 695, 'split_criterion': 0, 'bootstrap': False, 'max_samples': 0.9672911016703517, 'max_depth': 4070, 'max_leaves': 8312, 'max_features': 0.8439008867799189, 'n_bins': 957, 'min_samples_leaf': 0.005146045222101435, 'min_samples_split': 0.0016802880374141445, 'min_impurity_decrease': 0.015408388312653544}
# melhor Score:  0.010926365795724466

# %%
model = RandomForestClassifier(n_streams=1, n_estimators= 906, split_criterion= 0, bootstrap= False, max_samples= 0.3994317971682374, max_depth= 158, max_leaves= 318, max_features= 0.833192616970997, n_bins= 151, min_samples_leaf= 0.00909751610935131, min_samples_split= 0.0038673434907006963, min_impurity_decrease= 0.015037322312696668)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f'Precision: {precision}')
print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{confusion}')
print(f'Classification Report:\n{classification_rep}')


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plote a curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
print('=' * 70)
print('=' * 70)
# Out:
# [W] [23:11:42.677254] If bootstrap sampling is disabled, max_samples value is ignored and whole dataset is used for building each tree
# Precision: 0.011042944785276074
# Accuracy: 0.9246006509296323
# Confusion Matrix:
# [[49386  4030]
#  [    1    45]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.92      0.96     53416
#          1.0       0.01      0.98      0.02        46
#
#     accuracy                           0.92     53462
#    macro avg       0.51      0.95      0.49     53462
# weighted avg       1.00      0.92      0.96     53462
# ======================================================================
# ======================================================================

# %%
model = RandomForestClassifier(n_streams=40, n_estimators= 695, split_criterion= 0, bootstrap= False, max_samples= 0.9672911016703517, max_depth= 4070, max_leaves= 8312, max_features= 0.8439008867799189, n_bins= 957, min_samples_leaf= 0.005146045222101435, min_samples_split= 0.0016802880374141445, min_impurity_decrease= 0.015408388312653544)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f'Precision: {precision}')
print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{confusion}')
print(f'Classification Report:\n{classification_rep}')


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plote a curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
print('=' * 70)
print('=' * 70)

model.convert_to_treelite_model().to_treelite_checkpoint('/')
# Out:
# [W] [23:28:18.682112] If bootstrap sampling is disabled, max_samples value is ignored and whole dataset is used for building each tree
# Precision: 0.012064343163538873
# Accuracy: 0.931053832628783
# Confusion Matrix:
# [[49731  3685]
#  [    1    45]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.93      0.96     53416
#          1.0       0.01      0.98      0.02        46
#
#     accuracy                           0.93     53462
#    macro avg       0.51      0.95      0.49     53462
# weighted avg       1.00      0.93      0.96     53462
# ======================================================================
# ======================================================================

# %%
X_test.shape
# Out:
# (53462, 35)

# %%
import pickle

# %%
pickle.dump(model, open("RandomForestClassifier.pkl", "wb"))
